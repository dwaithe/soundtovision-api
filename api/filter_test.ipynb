# %% [markdown]
# ## Direct to Render Python and SToV Example
# ### 1.0) Introduction
# In this example we utilise many of the Sound To Vision (SToV) filters to create a video which showcases each of them.

# %% [markdown]
# #### 1.1) Dependencies

# %%
import sys
import math
import json
import shutil
import copy
import numpy as np
import matplotlib.pylab as plt
from datetime import datetime

from stovpy import utils, project, filters, audio, renderer
from stovpy import asset as ass

# %% [markdown]
# ### 2.0) Project Definition
# #### 2.1) Project script

# %%
proj_ = project.SToVProject()
json_var = proj_.rtn_json()

img_name = 'marek-okon-9gtODWv-L5I-unsplash.png'
img_path = os.path.join(os.getcwd(),'assets', img_name)

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 0, 7.688, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
ColorOverlayFilter = filters.SToVFilter('ColorOverlayFilter', True)
ColorOverlayFilter.set_prop_value('alpha', 0.51)
ColorOverlayFilter.set_prop_value('color', [0.8,0.2,0.2])
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = ColorOverlayFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}

asset = ass.SToVAsset(type_params['file_name'], 'photo', 7.688, 14.688000000000002, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
GlitchFilter = filters.SToVFilter('GlitchFilter', True)
GlitchFilter.set_prop_value('average', True)
GlitchFilter.set_prop_value('blue', [1607.66,2560.9])
GlitchFilter.set_prop_value('red', [1170.62,1768.48])
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = GlitchFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()


uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 14.687, 22.374, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
AdjustmentFilter = filters.SToVFilter('AdjustmentFilter', True)
AdjustmentFilter.set_prop_value('gamma', 3.06)
AdjustmentFilter.set_prop_value('red', 2.46)
AdjustmentFilter.set_prop_value('green', 2.68)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = AdjustmentFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 22.374, 29.68600000000001, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
AdvancedBloomFilter = filters.SToVFilter('AdvancedBloomFilter', True)
AdvancedBloomFilter.set_prop_value('bloomScale', 1.5)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = AdvancedBloomFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 29.687, 37.373999999999995, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
AsciiFilter = filters.SToVFilter('AsciiFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = AsciiFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 37.374, 45.061, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
GodrayFilter = filters.SToVFilter('GodrayFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = GodrayFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 45.061, 52.748, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
CRTFilter = filters.SToVFilter('CRTFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = CRTFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 52.748, 60.434999999999995, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
ShockwaveFilter = filters.SToVFilter('ShockwaveFilter', True)
ShockwaveFilter.set_prop_value('center', [431.11,307.88])
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = ShockwaveFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 60.435, 68.122, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
PixelateFilter = filters.SToVFilter('PixelateFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = PixelateFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 68.122, 75.809, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
ExtractFilter = filters.SToVFilter('ExtractFilter', True)
ExtractFilter.set_prop_value('keyColor', [0.3,0.1,0.1])
ExtractFilter.set_prop_value('similarity', 0.147)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = ExtractFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 75.808, 83.495, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
ChromaFilter = filters.SToVFilter('ChromaFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = ChromaFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 83.495, 91.182, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
CoarseNoiseFilter = filters.SToVFilter('CoarseNoiseFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = CoarseNoiseFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 91.182, 98.869, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
InvertFilter = filters.SToVFilter('InvertFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = InvertFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 98.869, 106.556, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
CycleThresholdShader = filters.SToVFilter('CycleThresholdShader', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = CycleThresholdShader.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 106.556, 114.243, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
NoiseFilter = filters.SToVFilter('NoiseFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = NoiseFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 114.243, 121.92999999999999, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
ReflectionFilter = filters.SToVFilter('ReflectionFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = ReflectionFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 121.93, 129.61700000000002, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
BlurFilter = filters.SToVFilter('BlurFilter', True)
BlurFilter.set_prop_value('blur', 28)
BlurFilter.set_prop_value('quality', 22)
BlurFilter.set_prop_value('resolution', 0)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = BlurFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 129.875, 137.562, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
RGBSplitFilter = filters.SToVFilter('RGBSplitFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = RGBSplitFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 137.562, 145.249, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
DotFilter = filters.SToVFilter('DotFilter', True)
asset.add_filter(funiqID)
json_var['project_file'][funiqID] = DotFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

uniqID = utils.generate_uniqID()
type_params = {'file_name':img_name,'fs':img_path, 'ftype':'full'}
asset = ass.SToVAsset(type_params['file_name'], 'photo', 145.249, 150.0, 0, 0, 1920, 1080, type_params)
asset.layer = 2
funiqID = utils.generate_uniqID()
TransitionFilter = filters.SToVFilter('TransitionFilter', True)
TransitionFilter.set_prop_value('nextImage', uniqID)
TransitionFilter.set_prop_value('dispFactor', 0.49)

asset.add_filter(funiqID)
json_var['project_file'][funiqID] = TransitionFilter.rtn_json()
json_var['project_file'][uniqID] = asset.rtn_json()

# %% [markdown]
# ### 3.0 Render
# #### 3.1) Setup render settings

# %%
#Render settings.
render_settings = {}
render_settings['fps'] = 60
render_settings['fourk'] = False
render_settings['render_id'] = 'filter_test'
render_settings['start_time'] = 0
render_settings['end_time'] = 150
render_settings['audio'] = False
render_settings['num_cores'] = 1
render_settings['limit_rate'] = 100

# %% [markdown]
# #### 3.2) Initialise render

# %%
#Initiate the renderer
render = renderer.SToVRender(json_var['project_file'], json_var['document_settings'], render_settings)

# %% [markdown]
# #### 3.3) Start Render

# %%
#Start the renderer.
render.start_render()
# Out:
#  render progress: [#########################] 100% FPS: 054.6 complete

# %% [markdown]
# ### 4.0 Results
# #### 4.1) Visualise Video Output

# %%
from IPython.display import Video
Video("test_outputs/s2v-filter_test.mp4", width=640, height=480)
# Out:
# <video src="test_outputs/s2v-filter_test.mp4" controls  width="640"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>
